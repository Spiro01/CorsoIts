# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pandasql import sqldf
def pysqldf(q): return sqldf(q, globals())

# %%
pokedex = pd.read_json("pokedex.json")

# %%
pysqldf("select * from pokedex")
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# c:\Users\User\Desktop\CorsoIts\BigData\jupyter\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1880                     self.dialect.do_executemany(
# -> 1881                         cursor, statement, parameters, context
#    1882                     )
#
# c:\Users\User\Desktop\CorsoIts\BigData\jupyter\lib\site-packages\sqlalchemy\engine\default.py in do_executemany(self, cursor, statement, parameters, context)
#     732     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 733         cursor.executemany(statement, parameters)
#     734
#
# InterfaceError: Error binding parameter 1 - probably unsupported type.
#
# The above exception was the direct cause of the following exception:
#
# ...
